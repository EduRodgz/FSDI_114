# %%
class Queue:
    class __Node:
        def __init__(self, data):
        self.data = data
        self.front = None
    def __init__(self):
        self.rear = None

    def enqueue(self, value):
       new_node = self.__Node(value)
        if not self.rear:
            self.rear = new_node
        else:
            old_previous = self.rear
            self.rear = new_node
            new_node.front = old_rear

    def dequeue(self):
        if self.front:
            datum = self.front.data
            self.front = self.top.front
            return datum
        raise IndexError("Queue is empty")


    def size(self):
        count = 0
        current = self.front
        while current:
            current = current.rear
            count += 1
        return count

    def peek(self):
        if self.rear:
            return self.rear.data
        raise IndexError("Queue is empty")
        
    def is_empty(self)
            if self.rear == None:
                return True
            return False

# %%
class QueueII:
    class __Node:
        def __init__(self,data):
            self.data = data
            self.previous = None

    def __init__(self):
        self.rear = None
        self.front = None
    def enqueue(self,value):
        new_node = self.__Node(value)
        if not self.front:
            self.rear = new_node
            self.front = new_node
        else:
            old_rear = self.rear
            old_rear.prev = new_node
            self.rear = new_node
            
    #def dequeue(self):
        #if self.front:
            #datum = self.front.data
            #current = self.rear
            #while current.next and current.next != self.front:
             #   current = current.next
            #current.next = None
            #return datum
        #raise IndexError("Queue is empty")

    def dequeue(self):
        if self.front:
            datum = self.front.data
            self.front = self.front.prev
            return datum
        raise IndexError("Queue is empty")

    def size(self):
        count = 0
        current = self.front
        while current:
            current = current.rear
            count += 1
        return count

    def peek(self):
        if self.rear:
            return self.rear.data
        raise IndexError("Queue is empty")
        
    def is_empty(self)
            if self.rear == None:
                return True
            return False

# %%
class SinglyLinkedList:
    class __Node:
         def __init__(self,data):
             self.data = data
             self.next = None
         
    def __init__(self):
        self.head

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def insert(self, index, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
        else:
            if index == 0:
                new_node.next = self.head
                self.head = new_node
            else:
                current = self.head
                count = 0
                prev = None
                while current.next and count != index:
                    prev = current
                    current = current.next
                    count +=1
                if count == index:
                    prev.next = new_node
                    new_node.next = current
                else:
                    current.next = new_node
        
    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % repr(current.data)
            current = current.next
            while current:
                out += ", %s" % repr(current.data)
                current = currrent.next
        out += "]"
        return out

# %%
mylist = []
sll = SinglyLinkedList()

print(sll)

sll.append(1)
print(sll)

sll.append(2)
print(sll)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 mylist = []
# ----> 2 sll = SinglyLinkedList()
#       4 print(sll)
#       6 sll.append(1)
#
# Cell In[19], line 8, in SinglyLinkedList.__init__(self)
#       7 def __init__(self):
# ----> 8     self.head
#
# AttributeError: 'SinglyLinkedList' object has no attribute 'head'
